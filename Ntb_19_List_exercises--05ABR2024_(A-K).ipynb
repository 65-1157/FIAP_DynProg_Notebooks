# %% [markdown]
# The following exercises shall be done and turned in by 05ABR2024 (Teams).

# %% [markdown]
# 1 - Develop a code to find all of the numbers from 1-1000 that are divisible by 13. You may use a 'loop-for' or 'list comprehension'.

# %% [markdown]
# 2 - Compare the time to run between a loop-for and list comprehension, considering the statement:
# "Find the common numbers in two lists (without using a tuple or set) list_a = [1,3,7,11,22,34,57,43,89,92,93]
# list_b = [1, 2, 3, 4, 5,11,22,23,34,56,89,92,43]"

# %% [markdown]
# 3 - With a nested list comprehension, find all of the numbers from [1-1000] that are divisible by any single digit within [2-7].

# %% [markdown]
# 4 - Define a function to compute 3 things: the quantity of numbers within a list, a list with the numbers from the list divisble by 2 or 3, and indicate the quantity of numbers not following this criteria. You may use list comprehension or loop-for.

# %% [markdown]
# 5 - Using the functions derived in the last question (#_4), show the result upon: a5 = [3,5,6,12,13,18,20,22,24,40,41,17,21,1004,49,51,44,63,66,79]
# b5 = [1,2,4,6,9,10,11,45,32,33,1308,88,67,47,56,89,95,92,100,16,15]
# c5 = [3,4,5,6,9,10,44,34,33,37,41,42,50,52,1404,53,67,58,68,72,74,75]

# %% [markdown]
# 6 - Explain the meaning of the following function: (Answer in Portuguese or English)

# %%
def menu_is_boring(meals):
    for i in range(len(meals)-1):
        if meals[i] == meals[i+1]:
            return True
    return False

# %% [markdown]
# 7 - Make a function to produce a new list, derived from an initial one, by adding 2 to all even numbers inside this initial list.

# %% [markdown]
# 8 - Apply the above function to the following initial lists:
# a = [2,3,5,6,7,8,11,13,14,15,17,18,19,20,2003,31,32,45,47]
# b = [3,4,5,6,99,8,24,32,33,35,37,23,73,77,81,83,85,89,93,96,99]
# Compute the time to run the function for the two cases.
